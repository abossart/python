# %%
import up42
import pandas as pd

#Authentication & initialisation
up42.authenticate(cfg_file="../secret/config.json")
project = up42.initialize_project()

#get workflows/jobs, storage and assets lists
workflow = project.get_jobs()
storage = up42.initialize_storage()
assets = storage.get_assets(limit=100, sortby="size", descending=False)


# displayTable function to display tables using panda
def displayTable(inputList, param1, param2, param3, param4, param5, message):
    list = []
    for x in inputList:
        list.append([x.info[param1],x.info[param2],x.info[param3],x.info[param4],x.info[param5]])
    df=pd.DataFrame(data=list, columns=[param1, param2, param3, param4, param5])
    print(message)
    display(df)

displayTable(workflow, "displayId", "status", "updatedAt", "name", "createdAt", "Jobs run by user")
displayTable(assets,"name", "source", "createdAt","size","orderId", "Available Assets in Storage")

print(assets)

#assets[0].download()
#assets[0].results

print(assets[3].info)
#print(assets[0].info,sep="\n") #display available info about Assets object

#workflow[5].download_quicklooks()
#workflow[5].map_quicklooks() #I get an error there
#up42.draw_aoi()

#workflow[3].download_results()
#workflow[3].map_results()
# Out:
# 2022-12-01 16:48:50,247 - Got credentials from config file.
# 2022-12-01 16:48:50,844 - Authentication with UP42 successful!
# 2022-12-01 16:48:51,016 - Initialized Project(name: Augustin Project Sandbox, project_id: d5d9dd71-d79b-4bf8-9ce3-93106dc2904e, description: , createdAt: 2022-08-16T15:34:42.333863Z)
# 2022-12-01 16:48:51,223 - Returning ['DRY_RUN', 'DEFAULT'] jobs.
# 2022-12-01 16:48:51,432 - Got 6 jobs (limit parameter 500) in project d5d9dd71-d79b-4bf8-9ce3-93106dc2904e.
# 2022-12-01 16:48:51,703 - Got 5 assets for workspace 87c3fc7f-08c0-49be-be74-d91d6fac726c.
# Jobs run by user
#   displayId     status                    updatedAt                     name  \
# 0  775bfa5c  SUCCEEDED  2022-09-20T15:03:40.526788Z          get spot images
# 1  a6f91565     FAILED  2022-09-20T12:32:37.786789Z          Test for AT-889
# 2  86574161  SUCCEEDED  2022-09-20T09:14:43.695702Z          Test for AT-889
# 3  c08f252c  SUCCEEDED  2022-08-17T12:27:30.367796Z  Test Building detection
# 4  df12b495  SUCCEEDED  2022-08-17T11:48:10.298225Z  Test Building detection
# 5  a74a309b  SUCCEEDED  2022-08-16T15:45:38.733165Z                Test NDVI
#
#                      createdAt
# 0  2022-09-20T15:02:53.324339Z
# 1  2022-09-20T12:32:07.007757Z
# 2  2022-09-20T09:13:08.232528Z
# 3  2022-08-17T12:10:06.938567Z
# 4  2022-08-17T11:29:55.888921Z
# 5  2022-08-16T15:42:50.201071Z
# Available Assets in Storage
#                                                 name source  \
# 0  oneatlas_1a5e78f6-01b5-47cf-9ea5-f6425def1b59.zip  ORDER
# 1  oneatlas_908af585-9c5f-4088-a993-801e1a2afd75.zip  ORDER
# 2  DS_SPOT7_202206231008235_FR1_FR1_FR1_FR1_E007N...  ORDER
# 3  oneatlas_38b2567e-ef54-43dc-b33e-5886112315b2.zip  ORDER
# 4  oneatlas_8c92e933-6c55-4f22-aaf8-8d3121095be7.zip  ORDER
#
#                      createdAt      size                               orderId
# 0  2022-12-01T14:53:28.928049Z   1610336  1a5e78f6-01b5-47cf-9ea5-f6425def1b59
# 1  2022-12-01T14:46:26.447340Z   1610346  908af585-9c5f-4088-a993-801e1a2afd75
# 2  2022-09-21T15:19:53.804072Z   2445312  5cc26c60-86d3-405c-882e-a5dfafd1d645
# 3  2022-12-01T15:03:25.808161Z  10029093  38b2567e-ef54-43dc-b33e-5886112315b2
# 4  2022-08-16T15:37:23.843736Z  26341684  8c92e933-6c55-4f22-aaf8-8d3121095be7
# [Asset(name: oneatlas_1a5e78f6-01b5-47cf-9ea5-f6425def1b59.zip, asset_id: 805de9a9-f3e3-4cc4-9251-8cd2b2f038de, type: ARCHIVED, source: ORDER, createdAt: 2022-12-01T14:53:28.928049Z, size: 1610336), Asset(name: oneatlas_908af585-9c5f-4088-a993-801e1a2afd75.zip, asset_id: 7b086174-7c33-479f-8a67-99084081291e, type: ARCHIVED, source: ORDER, createdAt: 2022-12-01T14:46:26.447340Z, size: 1610346), Asset(name: DS_SPOT7_202206231008235_FR1_FR1_FR1_FR1_E007N53_01222.tar, asset_id: 9743fce2-905c-4a87-a0bb-4ba12b063113, type: ARCHIVED, source: ORDER, createdAt: 2022-09-21T15:19:53.804072Z, size: 2445312), Asset(name: oneatlas_38b2567e-ef54-43dc-b33e-5886112315b2.zip, asset_id: 8432fb83-46f4-44d0-932e-b5d437973160, type: ARCHIVED, source: ORDER, createdAt: 2022-12-01T15:03:25.808161Z, size: 10029093), Asset(name: oneatlas_8c92e933-6c55-4f22-aaf8-8d3121095be7.zip, asset_id: 5d69c647-1976-48c1-b94c-4be66988605e, type: ARCHIVED, source: ORDER, createdAt: 2022-08-16T15:37:23.843736Z, size: 26341684)]
# {'id': '8432fb83-46f4-44d0-932e-b5d437973160', 'workspaceId': '87c3fc7f-08c0-49be-be74-d91d6fac726c', 'createdAt': '2022-12-01T15:03:25.808161Z', 'type': 'ARCHIVED', 'source': 'ORDER', 'name': 'oneatlas_38b2567e-ef54-43dc-b33e-5886112315b2.zip', 'size': 10029093, 'metadata': {'geometry': {'type': 'Polygon', 'coordinates': [[[13.389222621917726, 52.51330888180364], [13.388364315032959, 52.521313104243944], [13.369524478912355, 52.5213914417927], [13.369116783142092, 52.51326970584064], [13.389222621917726, 52.51330888180364]]], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'area': 1.190000057220459, 'sceneId': 'DS_PHR1A_202210261023104_FR1_PX_E013N52_0614_01724', 'productType': 'bundle', 'dataHostOrderId': '7ea0b4f9-dc9d-411e-8b99-927b8d41d2b1', 'acquisitionDate': None, 'resolution': None, 'collection': None, 'producer': None}, 'createdBy': {'id': 'system', 'type': 'INTERNAL'}, 'updatedBy': {'id': 'system', 'type': 'INTERNAL'}, 'updatedAt': '2022-12-01T15:03:30.737940Z', 'orderId': '38b2567e-ef54-43dc-b33e-5886112315b2'}

# %%
import up42
import pandas as pd
import json

#Authentication & initialisation
up42.authenticate(cfg_file="../secret/config.json")
project = up42.initialize_project()
catalog = up42.initialize_catalog()

#get products available in catalog
products = catalog.get_data_products(basic=True)


pd.set_option('display.max_columns', None)
#display(pd.DataFrame.from_dict(products))
display(pd.DataFrame.from_dict(products).transpose())

display(products)

aoi_geometry = up42.get_example_aoi()

search_parameters = catalog.construct_search_parameters(collections=["spot"],
                                                        geometry=aoi_geometry,
                                                        start_date="2022-06-01",
                                                        end_date="2022-12-31",
                                                        max_cloudcover=20,
                                                        sortby="cloudCoverage",
                                                        limit=10)

search_results = catalog.search(search_parameters)

display(pd.DataFrame.from_dict(search_results))


data_product_id = "acc3f9a4-b622-49c1-b1e1-c762aa3e7e13"
image_id = search_results.iloc[0]["id"]
order_parameters = catalog.construct_order_parameters(data_product_id=data_product_id,
                                                      image_id=image_id, 
                                                      aoi=aoi_geometry)
display(order_parameters)

catalog.estimate_order(order_parameters)

acceptance = input("enter yes or no to order")
if acceptance == "yes":
    order = catalog.place_order(order_parameters)
else:
    print("not ordered")

print("End of script")
#print(disp[0])
# Out:
# 2022-12-02 17:20:53,357 - Got credentials from config file.
# 2022-12-02 17:20:53,978 - Authentication with UP42 successful!
# 2022-12-02 17:20:54,189 - Initialized Project(name: Augustin Project Sandbox, project_id: d5d9dd71-d79b-4bf8-9ce3-93106dc2904e, description: , createdAt: 2022-08-16T15:34:42.333863Z)
#                                collection              host  \
# Near Space Labs - 30cm           nsl-30cm     nearspacelabs
# Capella Space GEC             capella-gec      capellaspace
# Capella Space GEO             capella-geo      capellaspace
# Capella Space SICD           capella-sicd      capellaspace
# Capella Space SLC             capella-slc      capellaspace
# Pléiades Neo                         pneo          oneatlas
# SPOT 6/7                             spot          oneatlas
# Pléiades                              phr          oneatlas
# TripleSat                       triplesat              21at
# WorldDEM Neo                 worlddem-neo  airbus-elevation
# NEXTMap One DSM            nextmapone-dsm          intermap
# NEXTMap One DTM            nextmapone-dtm          intermap
# NEXTMap One Bundle      nextmapone-bundle          intermap
# NEXTMap 6 DSM                nextmap6-dsm          intermap
# NEXTMap 6 DTM                nextmap6-dtm          intermap
# NEXTMap 6 Bundle          nextmap6-bundle          intermap
# NEXTMap 10 DSM              nextmap10-dsm          intermap
# NEXTMap 10 DTM              nextmap10-dtm          intermap
# NEXTMap 10 Bundle        nextmap10-bundle          intermap
#
#                                                             data_products
# Near Space Labs - 30cm  {'Display Full Scene': '7131f727-cdbb-46d4-a1e...
# Capella Space GEC       {'Full Scene': '96072809-d820-4cf9-86dd-d3bff3...
# Capella Space GEO       {'Full Scene': 'd66facaa-533f-49a2-849a-c2910a...
# Capella Space SICD      {'Full Scene': '8b0aed07-c565-4bf9-b719-401e69...
# Capella Space SLC       {'Full Scene': '1f2b0d7f-d3e2-4b3d-96b7-e7c184...
# Pléiades Neo            {'Analytic': '6f722fb5-0323-4c97-9b1e-22870325...
# SPOT 6/7                {'Analytic': 'b1f8c48e-d16b-44c4-a1bb-5e8a2489...
# Pléiades                {'Analytic': '4f1b2f62-98df-4c74-81f4-5dce45de...
# TripleSat               {'Analytic - 8 bit': '2398d8f5-5f7f-4596-884d-...
# WorldDEM Neo            {'WorldDEM Neo': 'ec016f4c-332c-4190-b18b-13fb...
# NEXTMap One DSM         {'intermap': '228eb747-2b8b-4f56-8ade-2efd844d...
# NEXTMap One DTM         {'intermap': 'da146ac4-7000-4d59-b488-3633f11b...
# NEXTMap One Bundle      {'intermap': '776cadc2-ccb7-4ca4-8077-fc679bf8...
# NEXTMap 6 DSM           {'intermap': '93f2014d-b34e-411a-9688-33e08419...
# NEXTMap 6 DTM           {'intermap': '337c01f4-d71a-4f2f-8aee-d2143156...
# NEXTMap 6 Bundle        {'intermap': 'ca213436-c8cf-42a9-a4a2-04eb2fa7...
# NEXTMap 10 DSM          {'intermap': '5a484ba9-b2b9-4385-a066-0f6d28f6...
# NEXTMap 10 DTM          {'intermap': '5908c45d-dd41-4fd2-b38f-759f23d2...
# NEXTMap 10 Bundle       {'intermap': '0253307a-0377-4cd4-bd1c-93ec06ba...
# {'Near Space Labs - 30cm': {'collection': 'nsl-30cm',
#   'host': 'nearspacelabs',
#   'data_products': {'Display Full Scene': '7131f727-cdbb-46d4-a1e7-77ac38b7bd02'}},
#  'Capella Space GEC': {'collection': 'capella-gec',
#   'host': 'capellaspace',
#   'data_products': {'Full Scene': '96072809-d820-4cf9-86dd-d3bff3337c35'}},
#  'Capella Space GEO': {'collection': 'capella-geo',
#   'host': 'capellaspace',
#   'data_products': {'Full Scene': 'd66facaa-533f-49a2-849a-c2910ac9dd31'}},
#  'Capella Space SICD': {'collection': 'capella-sicd',
#   'host': 'capellaspace',
#   'data_products': {'Full Scene': '8b0aed07-c565-4bf9-b719-401e692de4a6'}},
#  'Capella Space SLC': {'collection': 'capella-slc',
#   'host': 'capellaspace',
#   'data_products': {'Full Scene': '1f2b0d7f-d3e2-4b3d-96b7-e7c184df7952'}},
#  'Pléiades Neo': {'collection': 'pneo',
#   'host': 'oneatlas',
#   'data_products': {'Analytic': '6f722fb5-0323-4c97-9b1e-22870325b8db',
#    'Display': '17745de8-6e7d-4751-99cd-3f8e9e9d290e'}},
#  'SPOT 6/7': {'collection': 'spot',
#   'host': 'oneatlas',
#   'data_products': {'Analytic': 'b1f8c48e-d16b-44c4-a1bb-5e8a24892e69',
#    'Display': 'acc3f9a4-b622-49c1-b1e1-c762aa3e7e13'}},
#  'Pléiades': {'collection': 'phr',
#   'host': 'oneatlas',
#   'data_products': {'Analytic': '4f1b2f62-98df-4c74-81f4-5dce45deee99',
#    'Display': '647780db-5a06-4b61-b525-577a8b68bb54'}},
#  'TripleSat': {'collection': 'triplesat',
#   'host': '21at',
#   'data_products': {'Analytic - 8 bit': '2398d8f5-5f7f-4596-884d-345c0b07af14',
#    'Analytic - 16 bit': '37c26f4d-f6a9-47c9-ae4d-a095569ab8bc'}},
#  'WorldDEM Neo': {'collection': 'worlddem-neo',
#   'host': 'airbus-elevation',
#   'data_products': {'WorldDEM Neo': 'ec016f4c-332c-4190-b18b-13fb12519c40'}},
#  'NEXTMap One DSM': {'collection': 'nextmapone-dsm',
#   'host': 'intermap',
#   'data_products': {'intermap': '228eb747-2b8b-4f56-8ade-2efd844d3792'}},
#  'NEXTMap One DTM': {'collection': 'nextmapone-dtm',
#   'host': 'intermap',
#   'data_products': {'intermap': 'da146ac4-7000-4d59-b488-3633f11b6cb8'}},
#  'NEXTMap One Bundle': {'collection': 'nextmapone-bundle',
#   'host': 'intermap',
#   'data_products': {'intermap': '776cadc2-ccb7-4ca4-8077-fc679bf8376a'}},
#  'NEXTMap 6 DSM': {'collection': 'nextmap6-dsm',
#   'host': 'intermap',
#   'data_products': {'intermap': '93f2014d-b34e-411a-9688-33e084190b68'}},
#  'NEXTMap 6 DTM': {'collection': 'nextmap6-dtm',
#   'host': 'intermap',
#   'data_products': {'intermap': '337c01f4-d71a-4f2f-8aee-d21431565893'}},
#  'NEXTMap 6 Bundle': {'collection': 'nextmap6-bundle',
#   'host': 'intermap',
#   'data_products': {'intermap': 'ca213436-c8cf-42a9-a4a2-04eb2fa7c9d6'}},
#  'NEXTMap 10 DSM': {'collection': 'nextmap10-dsm',
#   'host': 'intermap',
#   'data_products': {'intermap': '5a484ba9-b2b9-4385-a066-0f6d28f6ad8f'}},
#  'NEXTMap 10 DTM': {'collection': 'nextmap10-dtm',
#   'host': 'intermap',
#   'data_products': {'intermap': '5908c45d-dd41-4fd2-b38f-759f23d25ebf'}},
#  'NEXTMap 10 Bundle': {'collection': 'nextmap10-bundle',
#   'host': 'intermap',
#   'data_products': {'intermap': '0253307a-0377-4cd4-bd1c-93ec06ba7f4a'}}}
# 2022-12-02 17:20:54,571 - Getting small example aoi in location 'Berlin'.
# 2022-12-02 17:20:54,669 - Searching catalog with search_parameters: {'datetime': '2022-06-01T00:00:00Z/2022-12-31T23:59:59Z', 'intersects': {'type': 'Polygon', 'coordinates': (((13.375777664180191, 52.51799543512652), (13.375777664180191, 52.514561554285706), (13.381566455794598, 52.514561554285706), (13.381566455794598, 52.51799543512652), (13.375777664180191, 52.51799543512652)),)}, 'limit': 10, 'collections': ['spot'], 'query': {'cloudCoverage': {'lte': 20}}, 'sortby': [{'field': 'properties.cloudCoverage', 'direction': 'asc'}]}
# 2022-12-02 17:20:56,854 - 1 results returned.
#                                             geometry  \
# 0  POLYGON ((12.82281 52.93924, 12.82453 52.40110...
#
#                                      id constellation collection providerName  \
# 0  a8d15fa5-e0f3-41a3-b962-e548812c46ed          spot       spot     oneatlas
#
#   up42:usageType                                 providerProperties  \
# 0         [DATA]  {'qualified': False, 'acquisitionStation': 'FR...
#
#                                 sceneId producer           acquisitionDate  \
# 0  a8d15fa5-e0f3-41a3-b962-e548812c46ed   airbus  2022-06-05T09:56:11.249Z
#
#   start_datetime end_datetime  cloudCoverage  resolution deliveryTime
# 0           None         None           10.0         1.5        HOURS
# 2022-12-02 17:20:56,874 - See `catalog.get_data_product_schema(data_product_id)` for more detail on the parameter options.
# {'dataProduct': 'acc3f9a4-b622-49c1-b1e1-c762aa3e7e13',
#  'params': {'id': 'a8d15fa5-e0f3-41a3-b962-e548812c46ed',
#   'aoi': {'type': 'Polygon',
#    'coordinates': (((13.375777664180191, 52.51799543512652),
#      (13.375777664180191, 52.514561554285706),
#      (13.381566455794598, 52.514561554285706),
#      (13.381566455794598, 52.51799543512652),
#      (13.375777664180191, 52.51799543512652)),)}}}
# 2022-12-02 17:20:59,560 - Order is estimated to cost 57 UP42 credits (order_parameters: {'dataProduct': 'acc3f9a4-b622-49c1-b1e1-c762aa3e7e13', 'params': {'id': 'a8d15fa5-e0f3-41a3-b962-e548812c46ed', 'aoi': {'type': 'Polygon', 'coordinates': (((13.375777664180191, 52.51799543512652), (13.375777664180191, 52.514561554285706), (13.381566455794598, 52.514561554285706), (13.381566455794598, 52.51799543512652), (13.375777664180191, 52.51799543512652)),)}}})
# enter yes or no to orderno
# not ordered
# End of script

# %%
import up42
import pandas as pd

up42.authenticate(cfg_file="../secret/config.json")
storage = up42.initialize_storage()
assets = storage.get_assets(limit=100, sortby="size", descending=False)
#print("List of all assets available (100 records max)",*assets, sep="\n")
#print("\n")

print(assets[1].info,sep="\n") #display available info about Assets object

assetsTable = []

for x in assets:
    assetsTable.append([x.info["name"],x.info["type"],x.info["createdAt"],x.info["size"],x.info["orderId"]])
    


df=pd.DataFrame(data=assetsTable, columns=['Name', 'type', 'createdAt','size','orderId'])

display(df)

#assets[0].download()
#assets[0].results
# Out:
# 2022-11-29 17:29:09,569 - Got credentials from config file.
# 2022-11-29 17:29:10,082 - Authentication with UP42 successful!
# 2022-11-29 17:29:10,285 - Got 2 assets for workspace 87c3fc7f-08c0-49be-be74-d91d6fac726c.
# {'id': '5d69c647-1976-48c1-b94c-4be66988605e', 'workspaceId': '87c3fc7f-08c0-49be-be74-d91d6fac726c', 'createdAt': '2022-08-16T15:37:23.843736Z', 'type': 'ARCHIVED', 'source': 'ORDER', 'name': 'oneatlas_8c92e933-6c55-4f22-aaf8-8d3121095be7.zip', 'size': 26341684, 'metadata': {'geometry': {'type': 'Polygon', 'coordinates': [[[2.3079059381001863, 48.85648473591429], [2.3081690550358918, 48.85823919212579], [2.3079068779045637, 48.859993709833034], [2.307129428537252, 48.8616808604126], [2.3058665385152888, 48.863235797653246], [2.3041667096696172, 48.86459875127499], [2.302095254804825, 48.86571732613781], [2.2997317893932427, 48.866548518437085], [2.2971671703823047, 48.86706037099641], [2.2945, 48.86723320363725], [2.2918328296176957, 48.86706037099641], [2.2892682106067572, 48.866548518437085], [2.2869047451951756, 48.86571732613781], [2.2848332903303827, 48.86459875127499], [2.2831334614847116, 48.863235797653246], [2.2818705714627483, 48.8616808604126], [2.2810931220954362, 48.859993709833034], [2.280830944964108, 48.85823919212579], [2.281094061899814, 48.85648473591429], [2.2818723079948233, 48.85479776045984], [2.2831357303732402, 48.853243085312435], [2.284835746157672, 48.85188044085076], [2.286907014083782, 48.85076217514804], [2.2892699471389415, 48.849931244942034], [2.2918337694221504, 48.84941956750784], [2.2945, 48.84924679636276], [2.29716623057785, 48.84941956750784], [2.2997300528610585, 48.849931244942034], [2.3020929859162185, 48.85076217514804], [2.3041642538423286, 48.85188044085076], [2.3058642696267597, 48.853243085312435], [2.307127692005177, 48.85479776045984], [2.3079059381001863, 48.85648473591429]]], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'area': 3.130000114440918, 'sceneId': 'DS_PHR1B_202208111059031_FR1_PX_E002N48_0521_01104', 'productType': 'bundle', 'dataHostOrderId': '7a04858b-95cb-4966-93ff-6e2366aa44df', 'acquisitionDate': None, 'resolution': None, 'collection': None, 'producer': None}, 'createdBy': {'id': 'system', 'type': 'INTERNAL'}, 'updatedBy': {'id': 'system', 'type': 'INTERNAL'}, 'updatedAt': '2022-08-16T15:37:28.167547Z', 'orderId': '8c92e933-6c55-4f22-aaf8-8d3121095be7'}
#                                                 Name      type  \
# 0  DS_SPOT7_202206231008235_FR1_FR1_FR1_FR1_E007N...  ARCHIVED
# 1  oneatlas_8c92e933-6c55-4f22-aaf8-8d3121095be7.zip  ARCHIVED
#
#                      createdAt      size                               orderId
# 0  2022-09-21T15:19:53.804072Z   2445312  5cc26c60-86d3-405c-882e-a5dfafd1d645
# 1  2022-08-16T15:37:23.843736Z  26341684  8c92e933-6c55-4f22-aaf8-8d3121095be7
